# %%
# %run main.py
# Out:
# Loading prepared data from ../data/seq+att/data_2.pt ...
# Number of examples: TRAIN-37876 VALID-2383 TEST-7134
# Loading prepared vocab from ../data/seq+att/vocab_2.pt ...
# Vocabulary size: 12614
# Starting Training!
# Training starts ...
# Valid Loss:  9.444204778274734
#
# ...
# ================================== Model Training ===================================
# ...
#
# [Train][ 1][100/592]   Average Loss: 6.139014874895413   TIME-0.63
# [Train][ 1][200/592]   Average Loss: 5.747474510630389   TIME-0.62
# [Train][ 1][300/592]   Average Loss: 5.901470796950397   TIME-0.63
# [Train][ 1][400/592]   Average Loss: 5.899890228949095   TIME-0.59
#
# --------------------------------- Model Evaulation ---------------------------------
# [Valid][ 1][400/592]   Valid Loss: 5.7131025268352555
# Saved model state to '../data/seq+att/model/state_epoch_1.model'
# Saved train state to '../data/seq+att/model/state_epoch_1.train'
# ...
